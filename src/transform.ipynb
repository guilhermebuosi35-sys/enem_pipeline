# %% [markdown]
# ## Análise Exploratória de Dados (EDA)
#
# Fazemos a primeira análise sobre os dados coletados na Base do INEP

# %%
import pandas as pd
from pathlib import Path

# %%
caminho_resultados_2024 = '/home/guilherme-buosi/enem_pipeline/data/raw/2024/RESULTADOS_2024.csv'

resultados_2024 = pd.read_csv(caminho_resultados_2024, encoding="latin-1", sep=";", nrows=100)
# Out:
#    NU_SEQUENCIAL  NU_ANO   CO_ESCOLA  CO_MUNICIPIO_ESC  \
# 0         206403    2024  23052929.0         2301406.0
# 1        3604651    2024  42103770.0         4218004.0
# 2        1461268    2024         NaN               NaN
# 3        4301058    2024         NaN               NaN
# 4        3148322    2024  21150354.0         2100436.0
# 5        1035588    2024         NaN               NaN
# 6        3587454    2024  15585689.0         1501402.0
# 7         140768    2024         NaN               NaN
# 8        3541867    2024         NaN               NaN
# 9        3371353    2024         NaN               NaN
#
#           NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                  Aratuba       23.0        CE                     2.0
# 1                  Tijucas       42.0        SC                     4.0
# 2                      NaN        NaN       NaN                     NaN
# ...

# %% [markdown]
# ###  Informações contidas no dataset: `resultados_2024`

# %%
resultados_2024.head(10)
# Out:
#    NU_SEQUENCIAL  NU_ANO   CO_ESCOLA  CO_MUNICIPIO_ESC  \
# 0         206403    2024  23052929.0         2301406.0
# 1        3604651    2024  42103770.0         4218004.0
# 2        1461268    2024         NaN               NaN
# 3        4301058    2024         NaN               NaN
# 4        3148322    2024  21150354.0         2100436.0
# 5        1035588    2024         NaN               NaN
# 6        3587454    2024  15585689.0         1501402.0
# 7         140768    2024         NaN               NaN
# 8        3541867    2024         NaN               NaN
# 9        3371353    2024         NaN               NaN
#
#           NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                  Aratuba       23.0        CE                     2.0
# 1                  Tijucas       42.0        SC                     4.0
# 2                      NaN        NaN       NaN                     NaN
# ...

# %%
resultados_2024.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_SEQUENCIAL           100 non-null    int64
#  1   NU_ANO                  100 non-null    int64
#  2   CO_ESCOLA               36 non-null     float64
#  3   CO_MUNICIPIO_ESC        36 non-null     float64
#  4   NO_MUNICIPIO_ESC        36 non-null     str
#  5   CO_UF_ESC               36 non-null     float64
#  6   SG_UF_ESC               36 non-null     str
#  7   TP_DEPENDENCIA_ADM_ESC  36 non-null     float64
#  8   TP_LOCALIZACAO_ESC      36 non-null     float64
#  9   TP_SIT_FUNC_ESC         36 non-null     float64
#  10  CO_MUNICIPIO_PROVA      100 non-null    int64
#  11  NO_MUNICIPIO_PROVA      100 non-null    str
#  12  CO_UF_PROVA             100 non-null    int64
#  13  SG_UF_PROVA             100 non-null    str
# ...
